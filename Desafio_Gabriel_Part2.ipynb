# %% [markdown]
# <a href="https://colab.research.google.com/github/erickom8/Curso-API/blob/master/Desafio_Gabriel_Part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px

# %%
data_part1 = pd.read_csv('/content/generic_event_data_part1.csv')
data_part1
# Out:
#       Unique ID  Event ID  Start Year  End Year
# 0             1     War 1        1797      1800
# 1             2     War 2        1739      1745
# 2             3     War 3        1768      1771
# 3             4     War 4        1766      1767
# 4             5     War 5        1934      1939
# ...         ...       ...         ...       ...
# 1995       1996  War 1996        1899      1902
# 1996       1997  War 1997        1748      1752
# 1997       1998  War 1998        1954      1955
# 1998       1999  War 1999        1830      1831
# 1999       2000  War 2000        1775      1778
#
# [2000 rows x 4 columns]

# %%
data_part2 = pd.read_csv('/content/generic_event_data_part2.csv')
data_part2
# Out:
#       Unique ID                          Countries Involved Major Battles  \
# 0             1             Country F, Country C, Country D     Battle 15
# 1             2                        Country C, Country A     Battle 61
# 2             3             Country D, Country B, Country C     Battle 27
# 3             4                        Country F, Country C     Battle 76
# 4             5                        Country C, Country B     Battle 15
# ...         ...                                         ...           ...
# 1995       1996             Country D, Country E, Country F     Battle 49
# 1996       1997                        Country F, Country E      Battle 8
# 1997       1998  Country F, Country C, Country A, Country E     Battle 48
# 1998       1999             Country C, Country D, Country E      Battle 2
# 1999       2000                        Country C, Country B     Battle 35
#
#            Outcome  Casualties
# 0          Victory        3120
# ...

# %% [markdown]
# 4. Países Mais Envolvidos: Quais países aparecem com mais frequência na coluna "Countries Involved".

# %%
virgula = data_part2.assign(Column1 = data_part2['Countries Involved'].str.split(',')).explode('Column1')

paises_envolvidos = virgula['Column1'].str.strip().value_counts()
print(paises_envolvidos)
# Out:
# Country D    1020
# Country A    1012
# Country E    1002
# Country C    1001
# Country B     983
# Country F     972
# Name: Column1, dtype: int64
